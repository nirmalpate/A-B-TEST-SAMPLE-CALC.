# %% [markdown]
# <a href="https://colab.research.google.com/github/nirmalpate/A-B-TEST-SAMPLE-CALC./blob/main/sampling_calculation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
# Parameters from Data

# %%
base_mean = 10
variance = 20
mde_lft = 10
alpha = 0.05
power = 0.80

# %%
#delta calculation

# %%
target_mean = base_mean * ( 1+ (mde_lft/100))
delta = target_mean - base_mean
delta_sq = delta * delta
delta_sq
# Out:
# 1.0

# %%
pooled_variance = 2 * variance
pooled_variance
# Out:
# 40

# %%
z_constant = (1.96 + power) **2

# %%
z_constant
# Out:
# 7.617599999999999

# %%
sample = (z_constant * pooled_variance) / delta_sq
sample
# Out:
# 304.70399999999995

# %%
total_sample = 2 * sample
total_sample
# Out:
# 609.4079999999999
